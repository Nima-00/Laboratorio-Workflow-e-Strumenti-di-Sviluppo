# %% [markdown]
# # Tools di un programmatore

# %% [markdown]
# Per rendere più facile lo sviluppo e la manutenzione del codice sono stati sviluppati una serie di tools che sono ormai richiesti ad ogni programmatore. In questa repo introduciamo quelli più comuni:
# - **Programmazione Modulare -> Come strutturare la repo**
# - **Il Readme**
# - **Pip**
# - **Shortcuts**
# - **git**
# - **GitHub**
# <!-- - **Virtual Environments** -->
# - **Debugger**
# - **Gestione Errori**
# <!-- - **Testing** -->
# <!-- - **Pyproject** -->
# <!-- - **Docker** -->
# - **Numpy**
# - **Matplotlib**
# <!-- - **Pandas** -->

# %% [markdown]
# ## GitHub

# %% [markdown]
# ```bash
# git remote
# git remote remove origin
# git push origin main
# git pull origin main
# git clone ...
# ```

# %% [markdown]
# ## Formatter

# %% [markdown]
# **Black Formatter**

# %% [markdown]
# ## Debugger

# %% [markdown]
# ## Pip

# %% [markdown]
# ```bash
# pip install numpy
# pip freeze
# ```

# %% [markdown]
# ## Shortcuts

# %% [markdown]
# - Ctrl + A
# - Ctrl + C
# - Ctrl + X
# - Ctrl + V
# - F12
# - F5
# - Ctrl + F
# - Ctrl + Shft + L
# - Ctrl + Alt + freccetta
# - Alt + freccetta
# - Ctrl + K + 0
