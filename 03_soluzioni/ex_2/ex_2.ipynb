# %% [markdown]
# # Foglio Esercizi 2

# %% [markdown]
# ### Ex 1: Crea una funzione che prende in input due matrici e restituisce la somma elemento per elemento

# %% [markdown]
# ### Ex 2: Scrivi una funzione che prende in input una matrice e restituisce il numero di volte che compare la cifra 2

# %% [markdown]
# ### Ex 3: Scrivi una funzione che prende in input una matrice e restituisce la somma degli elementi divisibili per 3

# %% [markdown]
# ### Ex 4: Scrivi una funzione che prende in input una matrice e restituisce la posizione degli 0

# %% [markdown]
# ### Ex 5: Scrivi una funzione che prende in input una matrice e restituisce la matrice trasposta
