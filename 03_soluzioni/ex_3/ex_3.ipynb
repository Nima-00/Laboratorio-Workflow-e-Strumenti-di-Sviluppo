# %% [markdown]
# # Foglio Esercizi 3

# %%
import numpy as np
import ex_3_utils

# %% [markdown]
# ### Ex 1: Scrivi una funzione che prende in input una matrice e restituisce `True` se è diagonale, `False` altrimenti

# %%
# Esempio
A = np.array([[1, 0, 0], [0, 2, 0], [0, 0, 3]])
diag = ex_3_utils.fun_1(A)
if diag:
    print("Diagonale")
else:
    print("Non diagonale")
# Out:
# Diagonale

# %% [markdown]
# ### Ex 2: Scrivi una funzione che prende in input una matrice e restituisce `True` se è simmetrica, `False` altrimenti

# %%
# Esempio
A = np.array([[1, 0, 0], [0, 2, 0], [0, 0, 3]])
sim = ex_3_utils.fun_2(A)
if sim:
    print("Simmetrica")
else:
    print("Non Simetrica")
# Out:
# Simmetrica

# %% [markdown]
# ### Ex 3: Scrivi una funzione che prende in input una matrice e restituisce `True` se è triangolare, `False` altrimenti

# %%
# Esempio
A = np.array([[1, 0, 0], [0, 2, 0], [0, 0, 3]])
triang = ex_3_utils.fun_3(A)
if triang:
    print("Triangolare Inferiore")
else:
    print("Non Triangolare Inferiore")
# Out:
# Triangolare Inferiore

# %% [markdown]
# ### Ex 4: Scrivi una funzione che prende in input una matrice e due interi i e j, resituisce la somma degli elementi della matrice esclusa la riga i e la colonna j

# %%
# Esempio
A = np.array([[1, 0, 0], [0, 2, 0], [0, 0, 3]])
s = ex_3_utils.fun_4(A, 0, 1)
print(s)
# Out:
# 3

# %% [markdown]
# ### Ex 5: Scrivi una funzione che prende in input una matrice e due interi i e j, resituisce la matrice ottenuta rimuovendo la riga i e la colonna j

# %%
# Esempio
A = np.array([[1, 0, 0], [0, 2, 0], [0, 0, 3]])
C = ex_3_utils.fun_5(A, 2, 2)
print(C)
# Out:
# [[1. 0.]
#  [0. 2.]]
